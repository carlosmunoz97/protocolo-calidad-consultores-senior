# %% [markdown]
# # Carga de datos - Auditoría y Transparencia
#
# Carga de los datasets: feedback de clientes, inventario central y transacciones logística.

# %%
import pandas as pd

# Cargar los tres datasets
df_feedback = pd.read_csv("feedback_clientes_v2.csv")
df_inventario = pd.read_csv("inventario_central_v2.csv")
df_transacciones = pd.read_csv("transacciones_logistica_v2.csv")

print("Dimensiones:")
print("  Feedback clientes:", df_feedback.shape)
print("  Inventario central:", df_inventario.shape)
print("  Transacciones logística:", df_transacciones.shape)
# Out:
# Dimensiones:
#   Feedback clientes: (4500, 9)
#   Inventario central: (2500, 8)
#   Transacciones logística: (10000, 10)

# %%
# Primeras 20 muestras - Feedback clientes
df_feedback.head(20)
# Out:
#    Feedback_ID Transaccion_ID  Rating_Producto  Rating_Logistica  \
# 0      FB-8000      TRX-17461               99                 4
# 1      FB-8001      TRX-17755                4                 5
# 2      FB-8002      TRX-10534                3                 4
# 3      FB-8003      TRX-12569                2                 3
# 4      FB-8004      TRX-19159                4                 2
# 5      FB-8005      TRX-16051                5                 3
# 6      FB-8006      TRX-11945                1                 1
# 7      FB-8007      TRX-19856                3                 4
# 8      FB-8008      TRX-16694                1                 4
# 9      FB-8009      TRX-11807                1                 4
# 10     FB-8010      TRX-11980                1                 5
# 11     FB-8011      TRX-16055                5                 5
# 12     FB-8012      TRX-19367                2                 3
# ...

# %%
# Primeras 20 muestras - Inventario central
df_inventario.head(20)
# Out:
#        SKU_ID    Categoria  Stock_Actual  Costo_Unitario_USD  Punto_Reorden  \
# 0   PROD-1000  smart-phone           NaN              870.38            259
# 1   PROD-1001   Accesorios         476.0             1397.26            169
# 2   PROD-1002    Monitores        1209.0              611.62            214
# 3   PROD-1003  smart-phone        1825.0              145.94            187
# 4   PROD-1004  Smartphones        1713.0               77.78            105
# 5   PROD-1005          ???         470.0             1248.94            126
# 6   PROD-1006    Monitores        1651.0              810.87            181
# 7   PROD-1007    Monitores         966.0             1174.10            187
# 8   PROD-1008  smart-phone         963.0              389.92            219
# 9   PROD-1009      Tablets          66.0              550.37            123
# 10  PROD-1010  Smartphones        1317.0                0.05            201
# ...

# %%
# Primeras 20 muestras - Transacciones logística
df_transacciones.head(20)
# Out:
#    Transaccion_ID     SKU_ID Fecha_Venta  Cantidad_Vendida  \
# 0       TRX-10000  PROD-3619  25/04/2025                -5
# 1       TRX-10001  PROD-1456  29/07/2025                12
# 2       TRX-10002  PROD-1102  31/05/2025                 2
# 3       TRX-10003  PROD-2126  23/01/2026                 4
# 4       TRX-10004  PROD-2003  09/10/2025                 5
# 5       TRX-10005  PROD-1914  05/11/2025                 2
# 6       TRX-10006  PROD-1571  20/06/2025                12
# 7       TRX-10007  PROD-1419  18/11/2025                 8
# 8       TRX-10008  PROD-3771  03/11/2025                 1
# 9       TRX-10009  PROD-3233  21/03/2025                 3
# 10      TRX-10010  PROD-1356  04/04/2025                 7
# 11      TRX-10011  PROD-3418  07/12/2025                10
# 12      TRX-10012  PROD-2728  01/08/2025                 1
# 13      TRX-10013  PROD-1130  10/12/2024                13
# 14      TRX-10014  PROD-1122  21/03/2025                11
# ...
